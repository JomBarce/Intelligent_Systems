# %% [markdown]
# ##### Programming Exercise by Jomer Allan G. Barcenilla Based on:
# UNDERSTANDING DEEP LEARNING REQUIRES RETHINKING GENERALIZATION
# - Chiyuan Zhang, Samy Bengio, Moritz Hardt, Benjamin Recht, & Oriol Vinyals

# %% [markdown]
# ### Import Libraries

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Concatenate, MaxPooling2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

# %% [markdown]
# ### Create the Inception Model

# %%
def conv_module(x, filters, kernel_size, strides):
    x = Conv2D(filters, kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def inception_module(x, ch1, ch3):
    conv1 = conv_module(x, ch1, (1, 1), 1)
    conv2 = conv_module(x, ch3, (3, 3), 1)
    inception = Concatenate(axis=-1)([conv1, conv2])
    return inception

def downsample_module(x, ch3):
    conv1 = conv_module(x, ch3, (3, 3), 2)
    conv2 = conv_module(x, ch3, (3, 3), 2)
    x = Concatenate(axis=-1)([conv1, conv2])
    return x

def build_model():
    inputs = Input(shape=(28, 28, 3))
    x = inputs

    # Inception (Small)
    x = conv_module(x, 96, (3, 3), 1)
    x = inception_module(x, 32, 32)
    x = inception_module(x, 32, 48)
    x = downsample_module(x, 80)    
    x = inception_module(x, 112, 48)
    x = inception_module(x, 96, 64)
    x = inception_module(x, 80, 80)
    x = inception_module(x, 48, 96)
    x = downsample_module(x, 96)
    x = inception_module(x, 176, 160)
    x = inception_module(x, 176, 160)

    # Global Average Pooling
    x = AveragePooling2D(pool_size=(7, 7))(x)
    x = Flatten()(x)

    # Fully Connected layer
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

model = build_model()

# %%
# Show model summary
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 28, 28, 3)]          0         []
#
#  conv2d_134 (Conv2D)         (None, 28, 28, 96)           2688      ['input_7[0][0]']
#
#  batch_normalization_130 (B  (None, 28, 28, 96)           384       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  activation_130 (Activation  (None, 28, 28, 96)           0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 28, 28, 32)           3104      ['activation_130[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 28, 28, 32)           27680     ['activation_130[0][0]']
#
#  batch_normalization_131 (B  (None, 28, 28, 32)           128       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 28, 28, 32)           128       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_131 (Activation  (None, 28, 28, 32)           0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 28, 28, 32)           0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  concatenate_53 (Concatenat  (None, 28, 28, 64)           0         ['activation_131[0][0]',
#  e)                                                                  'activation_132[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 28, 28, 32)           2080      ['concatenate_53[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 48)           27696     ['concatenate_53[0][0]']
#
#  batch_normalization_133 (B  (None, 28, 28, 32)           128       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_134 (B  (None, 28, 28, 48)           192       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_133 (Activation  (None, 28, 28, 32)           0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  activation_134 (Activation  (None, 28, 28, 48)           0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  concatenate_54 (Concatenat  (None, 28, 28, 80)           0         ['activation_133[0][0]',
#  e)                                                                  'activation_134[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 14, 14, 80)           57680     ['concatenate_54[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 14, 14, 80)           57680     ['concatenate_54[0][0]']
#
#  batch_normalization_135 (B  (None, 14, 14, 80)           320       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_136 (B  (None, 14, 14, 80)           320       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 14, 14, 80)           0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_136 (Activation  (None, 14, 14, 80)           0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  concatenate_55 (Concatenat  (None, 14, 14, 160)          0         ['activation_135[0][0]',
#  e)                                                                  'activation_136[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 14, 14, 112)          18032     ['concatenate_55[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 14, 14, 48)           69168     ['concatenate_55[0][0]']
#
#  batch_normalization_137 (B  (None, 14, 14, 112)          448       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  batch_normalization_138 (B  (None, 14, 14, 48)           192       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_137 (Activation  (None, 14, 14, 112)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_138 (Activation  (None, 14, 14, 48)           0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  concatenate_56 (Concatenat  (None, 14, 14, 160)          0         ['activation_137[0][0]',
#  e)                                                                  'activation_138[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 14, 14, 96)           15456     ['concatenate_56[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 14, 14, 64)           92224     ['concatenate_56[0][0]']
#
#  batch_normalization_139 (B  (None, 14, 14, 96)           384       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 14, 14, 64)           256       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 14, 14, 96)           0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 14, 14, 64)           0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  concatenate_57 (Concatenat  (None, 14, 14, 160)          0         ['activation_139[0][0]',
#  e)                                                                  'activation_140[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 14, 14, 80)           12880     ['concatenate_57[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 14, 14, 80)           115280    ['concatenate_57[0][0]']
#
#  batch_normalization_141 (B  (None, 14, 14, 80)           320       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 14, 14, 80)           320       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_141 (Activation  (None, 14, 14, 80)           0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 14, 14, 80)           0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  concatenate_58 (Concatenat  (None, 14, 14, 160)          0         ['activation_141[0][0]',
#  e)                                                                  'activation_142[0][0]']
#
#  conv2d_147 (Conv2D)         (None, 14, 14, 48)           7728      ['concatenate_58[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 14, 14, 96)           138336    ['concatenate_58[0][0]']
#
#  batch_normalization_143 (B  (None, 14, 14, 48)           192       ['conv2d_147[0][0]']
#  atchNormalization)
#
#  batch_normalization_144 (B  (None, 14, 14, 96)           384       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_143 (Activation  (None, 14, 14, 48)           0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  activation_144 (Activation  (None, 14, 14, 96)           0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  concatenate_59 (Concatenat  (None, 14, 14, 144)          0         ['activation_143[0][0]',
#  e)                                                                  'activation_144[0][0]']
#
#  conv2d_149 (Conv2D)         (None, 7, 7, 96)             124512    ['concatenate_59[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 7, 7, 96)             124512    ['concatenate_59[0][0]']
#
#  batch_normalization_145 (B  (None, 7, 7, 96)             384       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  batch_normalization_146 (B  (None, 7, 7, 96)             384       ['conv2d_150[0][0]']
#  atchNormalization)
#
#  activation_145 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_145[0][0
#  )                                                                  ]']
#
#  activation_146 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_146[0][0
#  )                                                                  ]']
#
#  concatenate_60 (Concatenat  (None, 7, 7, 192)            0         ['activation_145[0][0]',
#  e)                                                                  'activation_146[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 7, 7, 176)            33968     ['concatenate_60[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 7, 7, 160)            276640    ['concatenate_60[0][0]']
#
#  batch_normalization_147 (B  (None, 7, 7, 176)            704       ['conv2d_151[0][0]']
#  atchNormalization)
#
#  batch_normalization_148 (B  (None, 7, 7, 160)            640       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  activation_147 (Activation  (None, 7, 7, 176)            0         ['batch_normalization_147[0][0
#  )                                                                  ]']
#
#  activation_148 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  concatenate_61 (Concatenat  (None, 7, 7, 336)            0         ['activation_147[0][0]',
#  e)                                                                  'activation_148[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 7, 7, 176)            59312     ['concatenate_61[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 7, 7, 160)            484000    ['concatenate_61[0][0]']
#
#  batch_normalization_149 (B  (None, 7, 7, 176)            704       ['conv2d_153[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 7, 7, 160)            640       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 7, 7, 176)            0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  activation_150 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_150[0][0
#  )                                                                  ]']
#
#  concatenate_62 (Concatenat  (None, 7, 7, 336)            0         ['activation_149[0][0]',
#  e)                                                                  'activation_150[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 1, 1, 336)            0         ['concatenate_62[0][0]']
#  gePooling2D)
#
#  flatten_6 (Flatten)         (None, 336)                  0         ['average_pooling2d_6[0][0]']
#
#  dense_6 (Dense)             (None, 10)                   3370      ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 1761578 (6.72 MB)
# Trainable params: 1757802 (6.71 MB)
# Non-trainable params: 3776 (14.75 KB)
# __________________________________________________________________________________________________
