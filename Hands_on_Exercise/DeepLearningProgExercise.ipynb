# %% [markdown]
# ##### Programming Exercise by Jomer Allan G. Barcenilla Based on:
# UNDERSTANDING DEEP LEARNING REQUIRES RETHINKING GENERALIZATION
# - Chiyuan Zhang, Samy Bengio, Moritz Hardt, Benjamin Recht, & Oriol Vinyals

# %% [markdown]
# ### Import Libraries

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Concatenate, MaxPooling2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

# %% [markdown]
# ### Create the Inception Model

# %%
def conv_module(x, filters, kernel_size, strides):
    x = Conv2D(filters, kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def inception_module(x, ch1, ch3):
    conv1 = conv_module(x, ch1, (1, 1), 1)
    conv2 = conv_module(x, ch3, (3, 3), 1)
    inception = Concatenate(axis=-1)([conv1, conv2])
    return inception

def downsample_module(x, ch3):
    conv1 = conv_module(x, ch3, (3, 3), 2)
    conv2 = conv_module(x, ch3, (3, 3), 2)
    x = Concatenate(axis=-1)([conv1, conv2])
    return x

def build_model():
    inputs = Input(shape=(28, 28, 3))
    x = inputs

    # Inception (Small)
    x = conv_module(x, 96, (3, 3), 1)
    x = inception_module(x, 32, 32)
    x = inception_module(x, 32, 48)
    x = downsample_module(x, 80)    
    x = inception_module(x, 112, 48)
    x = inception_module(x, 96, 64)
    x = inception_module(x, 80, 80)
    x = inception_module(x, 48, 96)
    x = downsample_module(x, 96)
    x = inception_module(x, 176, 160)
    x = inception_module(x, 176, 160)

    # Global Average Pooling
    x = AveragePooling2D(pool_size=(7, 7))(x)
    x = Flatten()(x)

    # Fully Connected layer
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

model = build_model()

# %%
# Show model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 28, 28, 96)           2688      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 28, 28, 96)           384       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 28, 28, 96)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)           3104      ['activation[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)           27680     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 28, 28, 32)           128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 28, 28, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 28, 28, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 28, 28, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 28, 28, 64)           0         ['activation_1[0][0]',
#                                                                      'activation_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)           2080      ['concatenate[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 48)           27696     ['concatenate[0][0]']
#
#  batch_normalization_3 (Bat  (None, 28, 28, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 28, 28, 48)           192       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 28, 28, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 28, 28, 48)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 28, 28, 80)           0         ['activation_3[0][0]',
#  )                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 80)           57680     ['concatenate_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 80)           57680     ['concatenate_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 14, 14, 80)           320       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 14, 14, 80)           320       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 14, 14, 80)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 14, 14, 80)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 14, 14, 160)          0         ['activation_5[0][0]',
#  )                                                                   'activation_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 112)          18032     ['concatenate_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 48)           69168     ['concatenate_2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 14, 14, 112)          448       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 14, 14, 48)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 14, 14, 112)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 14, 14, 48)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  concatenate_3 (Concatenate  (None, 14, 14, 160)          0         ['activation_7[0][0]',
#  )                                                                   'activation_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 96)           15456     ['concatenate_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 64)           92224     ['concatenate_3[0][0]']
#
#  batch_normalization_9 (Bat  (None, 14, 14, 96)           384       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 14, 14, 64)           256       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 14, 14, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 14, 14, 64)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 14, 14, 160)          0         ['activation_9[0][0]',
#  )                                                                   'activation_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 80)           12880     ['concatenate_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 80)           115280    ['concatenate_4[0][0]']
#
#  batch_normalization_11 (Ba  (None, 14, 14, 80)           320       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 14, 14, 80)           320       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 14, 14, 80)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 14, 14, 80)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  concatenate_5 (Concatenate  (None, 14, 14, 160)          0         ['activation_11[0][0]',
#  )                                                                   'activation_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 48)           7728      ['concatenate_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 96)           138336    ['concatenate_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, 14, 14, 48)           192       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 14, 14, 96)           384       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 14, 14, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 14, 14, 96)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 14, 14, 144)          0         ['activation_13[0][0]',
#  )                                                                   'activation_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 7, 7, 96)             124512    ['concatenate_6[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 96)             124512    ['concatenate_6[0][0]']
#
#  batch_normalization_15 (Ba  (None, 7, 7, 96)             384       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 7, 7, 96)             384       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 7, 7, 96)             0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 7, 7, 96)             0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  concatenate_7 (Concatenate  (None, 7, 7, 192)            0         ['activation_15[0][0]',
#  )                                                                   'activation_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 176)            33968     ['concatenate_7[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 160)            276640    ['concatenate_7[0][0]']
#
#  batch_normalization_17 (Ba  (None, 7, 7, 176)            704       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 7, 7, 160)            640       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 7, 7, 176)            0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 7, 7, 160)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  concatenate_8 (Concatenate  (None, 7, 7, 336)            0         ['activation_17[0][0]',
#  )                                                                   'activation_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 176)            59312     ['concatenate_8[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 7, 7, 160)            484000    ['concatenate_8[0][0]']
#
#  batch_normalization_19 (Ba  (None, 7, 7, 176)            704       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 7, 7, 160)            640       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 7, 7, 176)            0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 7, 7, 160)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_9 (Concatenate  (None, 7, 7, 336)            0         ['activation_19[0][0]',
#  )                                                                   'activation_20[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 336)            0         ['concatenate_9[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 336)                  0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 10)                   3370      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1761578 (6.72 MB)
# Trainable params: 1757802 (6.71 MB)
# Non-trainable params: 3776 (14.75 KB)
# __________________________________________________________________________________________________
